# %%
## Understanding the data
"""
Income column is the target variable
all the other potential inputs
"""
# Out:
# '\nIncome column is the target variable\nall the other potential inputs\n'

# %%
import pandas as pd

# %%
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data"
columns = ["age", "workclass", "fnlwgt", "education", "education-num", "marital-status", 
           "occupation", "relationship", "race", "sex", "capital-gain", "capital-loss", 
           "hours-per-week", "native-country", "income"]
df = pd.read_csv(url, names=columns, na_values=" ?", skipinitialspace=True)
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital-status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   32561 non-null  int64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  32561 non-null  object
#  14  income          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
o50 = pd.DataFrame()

for index, row in df.iterrows():
    if row["income"] == ">50K":
        o50 = pd.concat([o50, row.to_frame().T], ignore_index=True)
o50
# Out:
#      age         workclass  fnlwgt     education education-num  \
# 0     52  Self-emp-not-inc  209642       HS-grad             9
# 1     31           Private   45781       Masters            14
# 2     42           Private  159449     Bachelors            13
# 3     37           Private  280464  Some-college            10
# 4     30         State-gov  141297     Bachelors            13
# ...   ..               ...     ...           ...           ...
# 7836  71                 ?  287372     Doctorate            16
# 7837  39         Local-gov  111499    Assoc-acdm            12
# 7838  53           Private  321865       Masters            14
# 7839  40           Private  154374       HS-grad             9
# 7840  52      Self-emp-inc  287927       HS-grad             9
#
#           marital-status         occupation   relationship  \
# 0     Married-civ-spouse    Exec-managerial        Husband
# 1          Never-married     Prof-specialty  Not-in-family
# ...

# %%
# moving values from primary dataframe to specilised one
u50 = pd.DataFrame()

for index, row in df.iterrows():
    if row["income"] == "<=50K":
        u50 = pd.concat([u50, row.to_frame().T], ignore_index=True)
u50

# %%
u50 = u50.drop(columns=["capital-gain", "capital-loss"]) #removing useless rows
o50 = o50.drop(columns=["capital-gain", "capital-loss"])

# %%
#removing all the rows having 2 missing values

for index, row in o50.iterrows():
    if row["workclass"] == "?" and row["occupation"] == "?":
        o50.drop(index, inplace=True)

# %%
o50
# Out:
#      age         workclass  fnlwgt     education education-num  \
# 0     52  Self-emp-not-inc  209642       HS-grad             9
# 1     31           Private   45781       Masters            14
# 2     42           Private  159449     Bachelors            13
# 3     37           Private  280464  Some-college            10
# 4     30         State-gov  141297     Bachelors            13
# ...   ..               ...     ...           ...           ...
# 7835  38           Private  139180     Bachelors            13
# 7837  39         Local-gov  111499    Assoc-acdm            12
# 7838  53           Private  321865       Masters            14
# 7839  40           Private  154374       HS-grad             9
# 7840  52      Self-emp-inc  287927       HS-grad             9
#
#           marital-status         occupation   relationship  \
# 0     Married-civ-spouse    Exec-managerial        Husband
# 1          Never-married     Prof-specialty  Not-in-family
# ...
